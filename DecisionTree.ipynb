# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,accuracy_score

# %%
df = pd.read_csv('bank.csv')

# %%
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1
# 3    5      8       579         1     -1         0         3        1
# 4    5      8       673         2     -1         0         3        1

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome
# 0    5      8      1042         1     -1         0         3
# 1    5      8      1467         1     -1         0         3
# 2    5      8      1389         1     -1         0         3
# 3    5      8       579         1     -1         0         3
# 4    5      8       673         2     -1         0         3

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: deposit, dtype: int64

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.30,random_state = 1)

# %%
def mymodel(model):
    model.fit(xtrain,ytrain)
    ypred = model.predict(xtest)
    print(classification_report(ytest,ypred))

# %%
dt = DecisionTreeClassifier(criterion='entropy')
mymodel(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80      1760
#            1       0.79      0.74      0.77      1589
#
#     accuracy                           0.78      3349
#    macro avg       0.78      0.78      0.78      3349
# weighted avg       0.78      0.78      0.78      3349

# %%
dt.score(xtrain,ytrain)
# Out:
# 1.0

# %%
dt.score(xtest,ytest)
# Out:
# 0.7844132576888624

# %%
def mymodel1(model):
    model.fit(xtrain,ytrain)
    ypred = model.predict(xtest)
    print(classification_report(ytest,ypred))
    print('Training Score: ',model.score(xtrain,ytrain))
    print('Testing Score: ',model.score(xtest,ytest))

# %%
for i in range(1,31):
    dt1 = DecisionTreeClassifier(criterion='entropy',max_depth = i)
    dt1.fit(xtrain,ytrain)
    ypred = dt1.predict(xtest)
    ac = accuracy_score(ytest,ypred)
    print('max_depth: ',i,' accuracy score: ',ac)
# Out:
# max_depth:  1  accuracy score:  0.7121528814571514
# max_depth:  2  accuracy score:  0.7121528814571514
# max_depth:  3  accuracy score:  0.7584353538369663
# max_depth:  4  accuracy score:  0.774260973424903
# max_depth:  5  accuracy score:  0.7778441325768887
# max_depth:  6  accuracy score:  0.792773962376829
# max_depth:  7  accuracy score:  0.8068080023887728
# max_depth:  8  accuracy score:  0.8088981785607644
# max_depth:  9  accuracy score:  0.814272917288743
# max_depth:  10  accuracy score:  0.8148701104807405
# max_depth:  11  accuracy score:  0.8074051955807704
# max_depth:  12  accuracy score:  0.8091967751567632
# max_depth:  13  accuracy score:  0.8023290534487907
# max_depth:  14  accuracy score:  0.8005374738727978
# max_depth:  15  accuracy score:  0.797252911316811
# max_depth:  16  accuracy score:  0.787996416840848
# max_depth:  17  accuracy score:  0.7918781725888325
# max_depth:  18  accuracy score:  0.7939683487608241
# ...

# %%
dt2 = DecisionTreeClassifier(criterion='entropy',max_depth = 10)
mymodel1(dt2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1760
#            1       0.81      0.79      0.80      1589
#
#     accuracy                           0.82      3349
#    macro avg       0.82      0.81      0.81      3349
# weighted avg       0.82      0.82      0.82      3349
#
# Training Score:  0.8789197491360553
# Testing Score:  0.8154673036727381

# %%
for i in range(2,151):
    dt3 = DecisionTreeClassifier(criterion='entropy',min_samples_split = i)
    dt3.fit(xtrain,ytrain)
    ypred = dt3.predict(xtest)
    ac = accuracy_score(ytest,ypred)
    print('min_samples_split : ',i,' accuracy score : ',ac)
# Out:
# min_samples_split :  2  accuracy score :  0.7826216781128695
# min_samples_split :  3  accuracy score :  0.7814272917288743
# min_samples_split :  4  accuracy score :  0.7823230815168707
# min_samples_split :  5  accuracy score :  0.783517467900866
# min_samples_split :  6  accuracy score :  0.78501045088086
# min_samples_split :  7  accuracy score :  0.7853090474768588
# min_samples_split :  8  accuracy score :  0.7826216781128695
# min_samples_split :  9  accuracy score :  0.7862048372648551
# min_samples_split :  10  accuracy score :  0.7856076440728575
# min_samples_split :  11  accuracy score :  0.7832188713048671
# min_samples_split :  12  accuracy score :  0.7882950134368468
# min_samples_split :  13  accuracy score :  0.7900865930128397
# min_samples_split :  14  accuracy score :  0.7906837862048373
# min_samples_split :  15  accuracy score :  0.7921767691848313
# min_samples_split :  16  accuracy score :  0.7996416840848014
# ...

# %%
dt4 = DecisionTreeClassifier(criterion='entropy',min_samples_split = 53 )
mymodel1(dt4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83      1760
#            1       0.80      0.85      0.82      1589
#
#     accuracy                           0.82      3349
#    macro avg       0.82      0.82      0.82      3349
# weighted avg       0.82      0.82      0.82      3349
#
# Training Score:  0.8738000767950851
# Testing Score:  0.8232308151687071

# %%
for i in range(1,31):
    dt5 = DecisionTreeClassifier(criterion='entropy',min_samples_leaf = i)
    dt5.fit(xtrain,ytrain)
    ypred = dt5.predict(xtest)
    ac = accuracy_score(ytest,ypred)
    print('min_samples_leaf : ',i,' accuracy score : ',ac)
# Out:
# min_samples_leaf :  1  accuracy score :  0.7802329053448791
# min_samples_leaf :  2  accuracy score :  0.7766497461928934
# min_samples_leaf :  3  accuracy score :  0.7930725589728277
# min_samples_leaf :  4  accuracy score :  0.7936697521648253
# min_samples_leaf :  5  accuracy score :  0.7924753657808301
# min_samples_leaf :  6  accuracy score :  0.7945655419528217
# min_samples_leaf :  7  accuracy score :  0.8071065989847716
# min_samples_leaf :  8  accuracy score :  0.8115855479247537
# min_samples_leaf :  9  accuracy score :  0.8083009853687668
# min_samples_leaf :  10  accuracy score :  0.8038220364287847
# min_samples_leaf :  11  accuracy score :  0.8112869513287548
# min_samples_leaf :  12  accuracy score :  0.8154673036727381
# min_samples_leaf :  13  accuracy score :  0.8220364287847118
# min_samples_leaf :  14  accuracy score :  0.820244849208719
# min_samples_leaf :  15  accuracy score :  0.8250223947447
# min_samples_leaf :  16  accuracy score :  0.8199462526127202
# ...

# %%
df6 = DecisionTreeClassifier(criterion='entropy',min_samples_leaf = 15)
mymodel1(df6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83      1760
#            1       0.80      0.84      0.82      1589
#
#     accuracy                           0.83      3349
#    macro avg       0.83      0.83      0.83      3349
# weighted avg       0.83      0.83      0.83      3349
#
# Training Score:  0.8639447075387175
# Testing Score:  0.8253209913406987
